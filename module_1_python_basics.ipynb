# %%
#Python Basics Module 1

## 1. Data Types
age = 42
height = 1.65
name = "Lourdes"
is_student = True
type(age), type(height), type(name), type(is_student)

# %%
## 2. Type Conversion
float(age), int(height), str(age), bool(0), bool(5)

# %%
## 3. Operators
x, y = 9, 4
x+y, x-y, x*y, x/y, x//y, x%y

# %%
## 4. Variables
score = 10
score += 5
print("Final score:", score)

# %%
## 5. Strings
text = "Behavioral Data Science"
text[0], text[-1], text[0:10]

# %%
## 6. String Methods
msg = "  Hello World  "
msg.strip().upper(), msg.lower().replace("world", "python")

# %%
## Summary - Ready for Module 2!
